# %% [markdown]
# ## Set Up

# %%
# Clone the repository from github if not already setup
import os

dir_path = '/content/rPPG-Toolbox'
if os.path.isdir(dir_path):
  print(f"The directory '{dir_path}' exists.")
else:
  # !git clone https://github.com/trappertwo/rPPG-Toolbox.git
# %cd '{dir_path}'
# !ls '{dir_path}'
# Out:
# Cloning into 'rPPG-Toolbox'...
# remote: Enumerating objects: 3160, done.
# remote: Counting objects: 100% (1324/1324), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 3160 (delta 1223), reused 1132 (delta 1132), pack-reused 1836 (from 2)
# Receiving objects: 100% (3160/3160), 333.16 MiB | 31.98 MiB/s, done.
# Resolving deltas: 100% (2180/2180), done.
# Updating files: 100% (289/289), done.
# /content/rPPG-Toolbox
#  config.py	       LICENSE		  setup.sh
#  configs	       main.py		  tools
#  dataset	       model_outputs	  unsupervised_methods
#  evaluation	       neural_methods	 '<Updated>_rPPG_on_compressed_videos.ipynb'
#  figures	       README.md	  wip
#  final_model_release   requirements.txt

# %%
# Explicitly install PyQt5 to use interactive plotting and avoid non-interactive backends
# See this relevant issue for more details: https://github.com/astral-sh/uv/issues/6893
# This requires Python 3.9+
# !which python
# !python --version
# !pip install  --no-build-isolation PyQt5
# Out:
# /usr/local/bin/python
# Python 3.11.11
# Collecting PyQt5
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5)
#   Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.16-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 59.6 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.16-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 11.2 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 26.0 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.16 PyQt5-sip-12.17.0

# %%
### Setup using uv
### This gives an error when building the mamba package.
### Hence we need to directly install causal-conv1d and mamba-ssm.
### See README file under tools/mamba.
#!bash setup.sh uv
# %%bash
rm -rf .venv
uv venv --python 3.8
source .venv/bin/activate
uv pip install --no-build-isolation setuptools wheel
uv pip install --no-build-isolation torch==2.1.2+cu121 torchvision==0.16.2+cu121 torchaudio==2.1.2+cu121 --index-url https://download.pytorch.org/whl/cu121
uv pip install --no-build-isolation -r requirements.txt
uv pip install --no-build-isolation causal-conv1d
uv pip install --no-build-isolation mamba-ssm
# Out:
# Downloading cpython-3.8.20-linux-x86_64-gnu (19.9MiB)
#  Downloaded cpython-3.8.20-linux-x86_64-gnu
# Using CPython 3.8.20
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate
# Resolved 2 packages in 117ms
# Downloading setuptools (1.2MiB)
#  Downloaded setuptools
# Prepared 2 packages in 162ms
# Installed 2 packages in 87ms
#  + setuptools==75.3.0
#  + wheel==0.45.1
# Resolved 19 packages in 1.16s
# Downloading sympy (5.9MiB)
# Downloading pillow (4.3MiB)
# Downloading torch (2.0GiB)
# Downloading numpy (16.5MiB)
# Downloading torchvision (6.5MiB)
# Downloading torchaudio (3.2MiB)
# Downloading networkx (1.6MiB)
# Downloading triton (85.0MiB)
#  Downloaded torchaudio
#  Downloaded pillow
#  Downloaded networkx
#  Downloaded torchvision
#  Downloaded numpy
#  Downloaded sympy
#  Downloaded triton
#  Downloaded torch
# Prepared 19 packages in 39.29s
# Installed 19 packages in 472ms
#  + certifi==2022.12.7
#  + charset-normalizer==2.1.1
#  + filelock==3.13.1
#  + fsspec==2024.6.1
#  + idna==3.4
#  + jinja2==3.1.4
#  + markupsafe==2.1.5
#  + mpmath==1.3.0
#  + networkx==3.3
#  + numpy==1.24.1
#  + pillow==10.2.0
#  + requests==2.28.1
#  + sympy==1.13.1
#  + torch==2.1.2+cu121
#  + torchaudio==2.1.2+cu121
#  + torchvision==0.16.2+cu121
#  + triton==2.1.0
#  + typing-extensions==4.12.2
#  + urllib3==1.26.13
# Resolved 114 packages in 1.59s
# Downloading opencv-python (48.7MiB)
# Downloading scipy (24.5MiB)
# Downloading pandas (8.9MiB)
# Downloading scikit-image (11.8MiB)
# Downloading libclang (23.4MiB)
# Downloading numpy (16.1MiB)
# Downloading matplotlib (12.5MiB)
# Downloading tensorboard-data-server (6.3MiB)
# Downloading scikit-learn (25.5MiB)
# Downloading tensorflow-io-gcs-filesystem (2.3MiB)
# Downloading widgetsnbextension (2.2MiB)
# Downloading pywavelets (6.6MiB)
# Downloading debugpy (3.5MiB)
# Downloading tensorboard (5.4MiB)
# Downloading grpcio (5.7MiB)
# Downloading keras (1.7MiB)
# Downloading pygments (1.2MiB)
# Downloading jedi (1.5MiB)
# Downloading kiwisolver (1.1MiB)
# Downloading h5py (2.7MiB)
# Downloading timm (2.2MiB)
# Downloading tensorflow (558.8MiB)
#    Building jax==0.4.6
#    Building causal-conv1d==1.0.0
#  Downloaded kiwisolver
#  Downloaded pygments
#  Downloaded widgetsnbextension
#  Downloaded tensorflow-io-gcs-filesystem
#  Downloaded h5py
#  Downloaded debugpy
#  Downloaded timm
#  Downloaded grpcio
#  Downloaded tensorboard-data-server
#  Downloaded keras
#  Downloaded pywavelets
#  Downloaded tensorboard
#       Built jax==0.4.6
#  Downloaded scikit-image
#  Downloaded numpy
#  Downloaded matplotlib
#  Downloaded jedi
#  Downloaded pandas
#  Downloaded libclang
#  Downloaded scikit-learn
#  Downloaded opencv-python
#  Downloaded scipy
#       Built causal-conv1d==1.0.0
#  Downloaded tensorflow
# Prepared 96 packages in 23.85s
# Uninstalled 2 packages in 26ms
# Installed 96 packages in 813ms
#  + absl-py==2.1.0
#  + asttokens==3.0.0
#  + astunparse==1.6.3
#  + backcall==0.2.0
#  + beautifulsoup4==4.13.3
#  + cachetools==5.5.2
#  + causal-conv1d==1.0.0
#  + comm==0.2.2
#  + cycler==0.12.1
#  + debugpy==1.8.12
#  + decorator==5.1.1
#  + executing==2.2.0
#  + flatbuffers==25.2.10
#  - fsspec==2024.6.1
#  + fsspec==2024.10.0
#  + gast==0.4.0
#  + gdown==5.2.0
#  + google-auth==2.38.0
#  + google-auth-oauthlib==1.0.0
#  + google-pasta==0.2.0
#  + grpcio==1.70.0
#  + h5py==2.10.0
#  + huggingface-hub==0.29.1
#  + imageio==2.35.1
#  + importlib-metadata==8.5.0
#  + ipykernel==6.26.0
#  + ipython==8.12.3
#  + ipywidgets==8.1.1
#  + jax==0.4.6
#  + jedi==0.19.2
#  + joblib==1.4.2
#  + jupyter-client==8.6.3
#  + jupyter-core==5.7.2
#  + jupyterlab-widgets==3.0.13
#  + keras==2.12.0
#  + kiwisolver==1.4.7
#  + libclang==18.1.1
#  + markdown==3.7
#  + mat73==0.59
#  + matplotlib==3.1.2
#  + matplotlib-inline==0.1.7
#  + nest-asyncio==1.6.0
#  + ninja==1.11.1.3
#  - numpy==1.24.1
#  + numpy==1.22.0
#  + oauthlib==3.2.2
#  + opencv-python==4.5.2.54
#  + opt-einsum==3.4.0
#  + packaging==24.2
#  + pandas==1.1.5
#  + parso==0.8.4
#  + pexpect==4.9.0
#  + pickleshare==0.7.5
#  + platformdirs==4.3.6
#  + prompt-toolkit==3.0.50
#  + protobuf==3.20.3
#  + psutil==7.0.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pygments==2.19.1
#  + pyparsing==3.1.4
#  + pysocks==1.7.1
#  + python-dateutil==2.9.0.post0
#  + pytz==2025.1
#  + pywavelets==1.4.1
#  + pyyaml==6.0
#  + pyzmq==26.2.1
#  + requests-oauthlib==2.0.0
#  + retina-face==0.0.13
#  + rsa==4.9
#  + safetensors==0.5.2
#  + scikit-image==0.17.2
#  + scikit-learn==1.0.2
#  + scipy==1.5.2
#  + six==1.17.0
#  + soupsieve==2.6
#  + stack-data==0.6.3
#  + tensorboard==2.12.3
#  + tensorboard-data-server==0.7.2
#  + tensorboardx==2.4.1
#  + tensorflow==2.12.0
#  + tensorflow-estimator==2.12.0
#  + tensorflow-io-gcs-filesystem==0.34.0
#  + termcolor==2.4.0
#  + threadpoolctl==3.5.0
#  + tifffile==2023.7.10
#  + timm==1.0.11
#  + tornado==6.4.2
#  + tqdm==4.64.0
#  + traitlets==5.14.3
#  + wcwidth==0.2.13
#  + werkzeug==3.0.6
#  + widgetsnbextension==4.0.13
#  + wrapt==1.14.1
#  + yacs==0.1.8
#  + zipp==3.20.2
# Audited 1 package in 7ms
# Resolved 27 packages in 341ms
#    Building mamba-ssm==2.2.2
# Downloading transformers (9.6MiB)
# Downloading tokenizers (2.9MiB)
#  Downloaded tokenizers
#  Downloaded transformers
#       Built mamba-ssm==2.2.2
# Prepared 5 packages in 9.54s
# Installed 5 packages in 45ms
#  + einops==0.8.1
#  + mamba-ssm==2.2.2
#  + regex==2024.11.6
#  + tokenizers==0.20.3
#  + transformers==4.46.3

# %%
### List packages in the virtual environment
# !source .venv/bin/activate
# !uv pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      2.1.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# backcall                     0.2.0
# beautifulsoup4               4.13.3
# cachetools                   5.5.2
# causal-conv1d                1.0.0
# certifi                      2022.12.7
# charset-normalizer           2.1.1
# comm                         0.2.2
# cycler                       0.12.1
# debugpy                      1.8.12
# decorator                    5.1.1
# einops                       0.8.1
# executing                    2.2.0
# filelock                     3.13.1
# flatbuffers                  25.2.10
# fsspec                       2024.10.0
# gast                         0.4.0
# gdown                        5.2.0
# google-auth                  2.38.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.70.0
# h5py                         2.10.0
# huggingface-hub              0.29.1
# idna                         3.4
# imageio                      2.35.1
# importlib-metadata           8.5.0
# ipykernel                    6.26.0
# ipython                      8.12.3
# ipywidgets                   8.1.1
# jax                          0.4.6
# jedi                         0.19.2
# jinja2                       3.1.4
# joblib                       1.4.2
# jupyter-client               8.6.3
# jupyter-core                 5.7.2
# jupyterlab-widgets           3.0.13
# keras                        2.12.0
# kiwisolver                   1.4.7
# libclang                     18.1.1
# mamba-ssm                    2.2.2
# markdown                     3.7
# markupsafe                   2.1.5
# mat73                        0.59
# matplotlib                   3.1.2
# matplotlib-inline            0.1.7
# mpmath                       1.3.0
# nest-asyncio                 1.6.0
# networkx                     3.3
# ninja                        1.11.1.3
# numpy                        1.22.0
# oauthlib                     3.2.2
# opencv-python                4.5.2.54
# opt-einsum                   3.4.0
# packaging                    24.2
# pandas                       1.1.5
# parso                        0.8.4
# pexpect                      4.9.0
# pickleshare                  0.7.5
# pillow                       10.2.0
# platformdirs                 4.3.6
# prompt-toolkit               3.0.50
# protobuf                     3.20.3
# psutil                       7.0.0
# ptyprocess                   0.7.0
# pure-eval                    0.2.3
# pyasn1                       0.6.1
# pyasn1-modules               0.4.1
# pygments                     2.19.1
# pyparsing                    3.1.4
# pysocks                      1.7.1
# python-dateutil              2.9.0.post0
# pytz                         2025.1
# pywavelets                   1.4.1
# pyyaml                       6.0
# pyzmq                        26.2.1
# regex                        2024.11.6
# requests                     2.28.1
# requests-oauthlib            2.0.0
# retina-face                  0.0.13
# rsa                          4.9
# safetensors                  0.5.2
# scikit-image                 0.17.2
# scikit-learn                 1.0.2
# scipy                        1.5.2
# setuptools                   75.3.0
# six                          1.17.0
# soupsieve                    2.6
# stack-data                   0.6.3
# sympy                        1.13.1
# tensorboard                  2.12.3
# tensorboard-data-server      0.7.2
# tensorboardx                 2.4.1
# tensorflow                   2.12.0
# tensorflow-estimator         2.12.0
# tensorflow-io-gcs-filesystem 0.34.0
# termcolor                    2.4.0
# threadpoolctl                3.5.0
# tifffile                     2023.7.10
# timm                         1.0.11
# tokenizers                   0.20.3
# torch                        2.1.2+cu121
# torchaudio                   2.1.2+cu121
# torchvision                  0.16.2+cu121
# tornado                      6.4.2
# tqdm                         4.64.0
# traitlets                    5.14.3
# transformers                 4.46.3
# triton                       2.1.0
# typing-extensions            4.12.2
# urllib3                      1.26.13
# wcwidth                      0.2.13
# werkzeug                     3.0.6
# wheel                        0.45.1
# widgetsnbextension           4.0.13
# wrapt                        1.14.1
# yacs                         0.1.8
# zipp                         3.20.2

# %% [markdown]
# # PhysNet Training & Testing on Compressed Data

# %%
### UBFC-rPPG dataset in drive folder
### (TODO) Figure out how to import data set directly into colab
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### Train on (compressed) UBFC-RPPG dataset using PhysNet

# !source .venv/bin/activate && python main.py --config_file ./configs/train_configs/Compressed_UBFC-rPPG_UBFC-rPPG_UBFC-rPPG_PHYSNET_BASIC.yaml
# Out:
# => Merging a config file from ./configs/train_configs/Compressed_UBFC-rPPG_UBFC-rPPG_UBFC-rPPG_PHYSNET_BASIC.yaml
# Configuration:
# BASE: ['']
# DEVICE: cuda:0
# INFERENCE:
#   BATCH_SIZE: 2
#   EVALUATION_METHOD: FFT
#   EVALUATION_WINDOW:
#     USE_SMALLER_WINDOW: False
#     WINDOW_SIZE: 10
#   MODEL_PATH:
# LOG:
#   PATH: /content/drive/MyDrive/runs/exp/exp4
# MODEL:
#   BIGSMALL:
#     FRAME_DEPTH: 3
#   DROP_RATE: 0.2
#   EFFICIENTPHYS:
#     FRAME_DEPTH: 10
#   MODEL_DIR: /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels
#   NAME: Physnet
#   PHYSFORMER:
#     DIM: 96
#     FF_DIM: 144
#     NUM_HEADS: 4
#     NUM_LAYERS: 12
#     PATCH_SIZE: 4
#     THETA: 0.7
#   PHYSNET:
#     FRAME_NUM: 128
#   RESUME:
#   TSCAN:
#     FRAME_DEPTH: 10
#   iBVPNet:
#     CHANNELS: 3
#     FRAME_NUM: 160
# NUM_OF_GPU_TRAIN: 1
# TEST:
#   DATA:
#     BEGIN: 0.0
#     CACHED_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_test_preprocess/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse
#     DATASET: UBFC-rPPG
#     DATA_FORMAT: NCDHW
#     DATA_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_test
#     DO_PREPROCESS: True
#     END: 1.0
#     EXP_DATA_NAME: UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse
#     FILE_LIST_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_test_preprocess/DataFileLists/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse_0.0_1.0.csv
#     FILTERING:
#       EXCLUSION_LIST: ['']
#       SELECT_TASKS: False
#       TASK_LIST: ['']
#       USE_EXCLUSION_LIST: False
#     FOLD:
#       FOLD_NAME:
#       FOLD_PATH:
#     FS: 30
#     INFO:
#       EXERCISE: [True]
#       GENDER: ['']
#       GLASSER: [True]
#       HAIR_COVER: [True]
#       LIGHT: ['']
#       MAKEUP: [True]
#       MOTION: ['']
#       SKIN_COLOR: [1]
#     PREPROCESS:
#       BIGSMALL:
#         BIG_DATA_TYPE: ['']
#         RESIZE:
#           BIG_H: 144
#           BIG_W: 144
#           SMALL_H: 9
#           SMALL_W: 9
#         SMALL_DATA_TYPE: ['']
#       CHUNK_LENGTH: 128
#       CROP_FACE:
#         BACKEND: HC
#         DETECTION:
#           DO_DYNAMIC_DETECTION: False
#           DYNAMIC_DETECTION_FREQUENCY: 32
#           USE_MEDIAN_FACE_BOX: False
#         DO_CROP_FACE: True
#         LARGE_BOX_COEF: 1.5
#         USE_LARGE_FACE_BOX: True
#       DATA_AUG: ['None']
#       DATA_TYPE: ['DiffNormalized']
#       DO_CHUNK: True
#       IBVP:
#         DATA_MODE: RGB
#       LABEL_TYPE: DiffNormalized
#       RESIZE:
#         H: 72
#         W: 72
#       USE_PSUEDO_PPG_LABEL: False
#   METRICS: ['MAE', 'RMSE', 'MAPE', 'Pearson', 'SNR', 'BA']
#   OUTPUT_SAVE_DIR: /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/saved_test_outputs
#   USE_LAST_EPOCH: True
# TOOLBOX_MODE: train_and_test
# TRAIN:
#   BATCH_SIZE: 2
#   DATA:
#     BEGIN: 0.0
#     CACHED_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train_preprocess/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse
#     DATASET: UBFC-rPPG
#     DATA_FORMAT: NCDHW
#     DATA_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train
#     DO_PREPROCESS: True
#     END: 1.0
#     EXP_DATA_NAME: UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse
#     FILE_LIST_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train_preprocess/DataFileLists1/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse_0.0_1.0.csv
#     FILTERING:
#       EXCLUSION_LIST: ['']
#       SELECT_TASKS: False
#       TASK_LIST: ['']
#       USE_EXCLUSION_LIST: False
#     FOLD:
#       FOLD_NAME:
#       FOLD_PATH:
#     FS: 30
#     INFO:
#       EXERCISE: [True]
#       GENDER: ['']
#       GLASSER: [True]
#       HAIR_COVER: [True]
#       LIGHT: ['']
#       MAKEUP: [True]
#       MOTION: ['']
#       SKIN_COLOR: [1]
#     PREPROCESS:
#       BIGSMALL:
#         BIG_DATA_TYPE: ['']
#         RESIZE:
#           BIG_H: 144
#           BIG_W: 144
#           SMALL_H: 9
#           SMALL_W: 9
#         SMALL_DATA_TYPE: ['']
#       CHUNK_LENGTH: 128
#       CROP_FACE:
#         BACKEND: HC
#         DETECTION:
#           DO_DYNAMIC_DETECTION: False
#           DYNAMIC_DETECTION_FREQUENCY: 32
#           USE_MEDIAN_FACE_BOX: False
#         DO_CROP_FACE: True
#         LARGE_BOX_COEF: 1.5
#         USE_LARGE_FACE_BOX: True
#       DATA_AUG: ['None']
#       DATA_TYPE: ['DiffNormalized']
#       DO_CHUNK: True
#       IBVP:
#         DATA_MODE: RGB
#       LABEL_TYPE: DiffNormalized
#       RESIZE:
#         H: 72
#         W: 72
#       USE_PSUEDO_PPG_LABEL: False
#   EPOCHS: 30
#   LR: 0.009
#   MODEL_FILE_NAME: UBFC_UBFC_UBFC_physnet_stan
#   OPTIMIZER:
#     BETAS: (0.9, 0.999)
#     EPS: 0.0001
#     MOMENTUM: 0.9
#   PLOT_LOSSES_AND_LR: True
# UNSUPERVISED:
#   DATA:
#     BEGIN: 0.0
#     CACHED_PATH: PreprocessedData/_SizeW128_SizeH128_ClipLength180_DataType_DataAugNone_LabelType_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse_unsupervised
#     DATASET:
#     DATA_FORMAT: NDCHW
#     DATA_PATH:
#     DO_PREPROCESS: False
#     END: 1.0
#     EXP_DATA_NAME: _SizeW128_SizeH128_ClipLength180_DataType_DataAugNone_LabelType_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse_unsupervised
#     FILE_LIST_PATH: PreprocessedData/DataFileLists/_SizeW128_SizeH128_ClipLength180_DataType_DataAugNone_LabelType_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse_unsupervised_0.0_1.0.csv
#     FILTERING:
#       EXCLUSION_LIST: ['']
#       SELECT_TASKS: False
#       TASK_LIST: ['']
#       USE_EXCLUSION_LIST: False
#     FOLD:
#       FOLD_NAME:
#       FOLD_PATH:
#     FS: 0
#     INFO:
#       EXERCISE: [True]
#       GENDER: ['']
#       GLASSER: [True]
#       HAIR_COVER: [True]
#       LIGHT: ['']
#       MAKEUP: [True]
#       MOTION: ['']
#       SKIN_COLOR: [1]
#     PREPROCESS:
#       CHUNK_LENGTH: 180
#       CROP_FACE:
#         BACKEND: HC
#         DETECTION:
#           DO_DYNAMIC_DETECTION: False
#           DYNAMIC_DETECTION_FREQUENCY: 30
#           USE_MEDIAN_FACE_BOX: False
#         DO_CROP_FACE: True
#         LARGE_BOX_COEF: 1.5
#         USE_LARGE_FACE_BOX: True
#       DATA_AUG: ['None']
#       DATA_TYPE: ['']
#       DO_CHUNK: True
#       IBVP:
#         DATA_MODE: RGB
#       LABEL_TYPE:
#       RESIZE:
#         H: 128
#         W: 128
#       USE_PSUEDO_PPG_LABEL: False
#   METHOD: []
#   METRICS: []
#   OUTPUT_SAVE_DIR:
# VALID:
#   DATA:
#     BEGIN: 0.8
#     CACHED_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train_preprocess
#     DATASET: UBFC-rPPG
#     DATA_FORMAT: NCDHW
#     DATA_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train
#     DO_PREPROCESS: True
#     END: 1.0
#     EXP_DATA_NAME:
#     FILE_LIST_PATH: /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train_preprocess/DataFileLists2/
#     FILTERING:
#       EXCLUSION_LIST: ['']
#       SELECT_TASKS: False
#       TASK_LIST: ['']
#       USE_EXCLUSION_LIST: False
#     FOLD:
#       FOLD_NAME:
#       FOLD_PATH:
#     FS: 30
#     INFO:
#       EXERCISE: [True]
#       GENDER: ['']
#       GLASSER: [True]
#       HAIR_COVER: [True]
#       LIGHT: ['']
#       MAKEUP: [True]
#       MOTION: ['']
#       SKIN_COLOR: [1]
#     PREPROCESS:
#       BIGSMALL:
#         BIG_DATA_TYPE: ['']
#         RESIZE:
#           BIG_H: 144
#           BIG_W: 144
#           SMALL_H: 9
#           SMALL_W: 9
#         SMALL_DATA_TYPE: ['']
#       CHUNK_LENGTH: 128
#       CROP_FACE:
#         BACKEND: HC
#         DETECTION:
#           DO_DYNAMIC_DETECTION: False
#           DYNAMIC_DETECTION_FREQUENCY: 32
#           USE_MEDIAN_FACE_BOX: False
#         DO_CROP_FACE: True
#         LARGE_BOX_COEF: 1.5
#         USE_LARGE_FACE_BOX: True
#       DATA_AUG: ['None']
#       DATA_TYPE: ['DiffNormalized']
#       DO_CHUNK: True
#       IBVP:
#         DATA_MODE: RGB
#       LABEL_TYPE: DiffNormalized
#       RESIZE:
#         H: 72
#         W: 72
#       USE_PSUEDO_PPG_LABEL: False
#
# Preprocessing dataset...
#  53% 18/34 [03:44<02:44, 10.25s/it]Warning: More than one faces are detected. Only cropping the biggest one.
#  74% 25/34 [04:52<01:15,  8.36s/it]Warning: More than one faces are detected. Only cropping the biggest one.
# 100% 34/34 [06:00<00:00, 10.61s/it]
# Total Number of raw files preprocessed: 34
#
# Cached Data Path /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train_preprocess/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse
#
# File List Path /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_train_preprocess/DataFileLists1/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse_0.0_1.0.csv
#  train Preprocessed Dataset Length: 107
#
# Testing uses last epoch, validation dataset is not required.
#
# Preprocessing dataset...
# 100% 7/7 [01:13<00:00, 10.52s/it]
# Total Number of raw files preprocessed: 7
#
# Cached Data Path /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_test_preprocess/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse
#
# File List Path /content/drive/MyDrive/research_project/data/UBFC-rPPG/DATASET_50_1_test_preprocess/DataFileLists/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse_0.0_1.0.csv
#  test Preprocessed Dataset Length: 45
#
#
# ====Training Epoch: 0====
# Train epoch 0: 100%|█████████████████| 54/54 [00:13<00:00,  4.05it/s, loss=1.08]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch0.pth
#
# ====Training Epoch: 1====
# Train epoch 1: 100%|████████████████| 54/54 [00:09<00:00,  5.77it/s, loss=0.501]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch1.pth
#
# ====Training Epoch: 2====
# Train epoch 2: 100%|████████████████| 54/54 [00:09<00:00,  5.93it/s, loss=0.678]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch2.pth
#
# ====Training Epoch: 3====
# Train epoch 3: 100%|████████████████| 54/54 [00:09<00:00,  5.45it/s, loss=0.071]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch3.pth
#
# ====Training Epoch: 4====
# Train epoch 4: 100%|████████████████| 54/54 [00:09<00:00,  5.80it/s, loss=0.257]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch4.pth
#
# ====Training Epoch: 5====
# Train epoch 5: 100%|████████████████| 54/54 [00:09<00:00,  5.86it/s, loss=0.434]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch5.pth
#
# ====Training Epoch: 6====
# Train epoch 6: 100%|████████████████| 54/54 [00:10<00:00,  5.30it/s, loss=0.165]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch6.pth
#
# ====Training Epoch: 7====
# Train epoch 7: 100%|████████████████| 54/54 [00:09<00:00,  5.75it/s, loss=0.478]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch7.pth
#
# ====Training Epoch: 8====
# Train epoch 8: 100%|████████████████| 54/54 [00:09<00:00,  5.65it/s, loss=0.131]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch8.pth
#
# ====Training Epoch: 9====
# Train epoch 9: 100%|████████████████| 54/54 [00:09<00:00,  5.49it/s, loss=0.188]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch9.pth
#
# ====Training Epoch: 10====
# Train epoch 10: 100%|███████████████| 54/54 [00:09<00:00,  5.46it/s, loss=0.249]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch10.pth
#
# ====Training Epoch: 11====
# Train epoch 11: 100%|██████████████| 54/54 [00:09<00:00,  5.66it/s, loss=0.0596]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch11.pth
#
# ====Training Epoch: 12====
# Train epoch 12: 100%|███████████████| 54/54 [00:09<00:00,  5.63it/s, loss=0.161]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch12.pth
#
# ====Training Epoch: 13====
# Train epoch 13: 100%|███████████████| 54/54 [00:10<00:00,  5.03it/s, loss=0.092]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch13.pth
#
# ====Training Epoch: 14====
# Train epoch 14: 100%|███████████████| 54/54 [00:09<00:00,  5.46it/s, loss=0.112]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch14.pth
#
# ====Training Epoch: 15====
# Train epoch 15: 100%|██████████████| 54/54 [00:10<00:00,  5.40it/s, loss=0.0495]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch15.pth
#
# ====Training Epoch: 16====
# Train epoch 16: 100%|██████████████| 54/54 [00:09<00:00,  5.46it/s, loss=0.0353]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch16.pth
#
# ====Training Epoch: 17====
# Train epoch 17: 100%|██████████████| 54/54 [00:10<00:00,  5.17it/s, loss=0.0764]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch17.pth
#
# ====Training Epoch: 18====
# Train epoch 18: 100%|███████████████| 54/54 [00:10<00:00,  5.30it/s, loss=0.111]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch18.pth
#
# ====Training Epoch: 19====
# Train epoch 19: 100%|██████████████| 54/54 [00:09<00:00,  5.49it/s, loss=0.0402]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch19.pth
#
# ====Training Epoch: 20====
# Train epoch 20: 100%|███████████████| 54/54 [00:09<00:00,  5.50it/s, loss=0.107]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch20.pth
#
# ====Training Epoch: 21====
# Train epoch 21: 100%|██████████████| 54/54 [00:10<00:00,  5.14it/s, loss=0.0318]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch21.pth
#
# ====Training Epoch: 22====
# Train epoch 22: 100%|██████████████| 54/54 [00:10<00:00,  5.28it/s, loss=0.0499]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch22.pth
#
# ====Training Epoch: 23====
# Train epoch 23: 100%|██████████████| 54/54 [00:09<00:00,  5.48it/s, loss=0.0217]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch23.pth
#
# ====Training Epoch: 24====
# Train epoch 24: 100%|██████████████| 54/54 [00:09<00:00,  5.52it/s, loss=0.0178]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch24.pth
#
# ====Training Epoch: 25====
# Train epoch 25: 100%|███████████████| 54/54 [00:10<00:00,  5.13it/s, loss=0.049]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch25.pth
#
# ====Training Epoch: 26====
# Train epoch 26: 100%|██████████████| 54/54 [00:09<00:00,  5.41it/s, loss=0.0285]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch26.pth
#
# ====Training Epoch: 27====
# Train epoch 27: 100%|██████████████| 54/54 [00:09<00:00,  5.51it/s, loss=0.0202]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch27.pth
#
# ====Training Epoch: 28====
# Train epoch 28: 100%|█████████████| 54/54 [00:09<00:00,  5.52it/s, loss=0.00825]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch28.pth
#
# ====Training Epoch: 29====
# Train epoch 29: 100%|██████████████| 54/54 [00:10<00:00,  5.10it/s, loss=0.0187]
# Saved Model Path:  /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch29.pth
# The list of validation losses is empty. The validation loss will not be plotted!
# Saving plots of losses and learning rates to: /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/plots
#
# ===Testing===
# Testing uses last epoch as non-pretrained model!
# /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/PreTrainedModels/UBFC_UBFC_UBFC_physnet_stan_Epoch29.pth
# Running model evaluation on the testing dataset!
# 100%|███████████████████████████████████████████| 23/23 [00:02<00:00,  9.18it/s]
#
# Calculating metrics!
# 100%|█████████████████████████████████████████████| 3/3 [00:07<00:00,  2.51s/it]
# FFT MAE (FFT Label): 3.515625 +/- 2.870495792324037
# FFT RMSE (FFT Label): 6.089241120359334 +/- 5.502250476820151
# FFT MAPE (FFT Label): 2.73972602739726 +/- 2.2369769340485646
# FFT Pearson (FFT Label): 0.9856349387630817 +/- 0.16888980872005316
# FFT SNR (FFT Label): -2.0614852027377246 +/- 2.848187748481535 (dB)
# Saved UBFC_UBFC_UBFC_physnet_stan_FFT_BlandAltman_ScatterPlot.pdf to /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/bland_altman_plots.
# Saved UBFC_UBFC_UBFC_physnet_stan_FFT_BlandAltman_DifferencePlot.pdf to /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/bland_altman_plots.
# Saving outputs to: /content/drive/MyDrive/runs/exp/exp4/UBFC-rPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceTrue_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len32_Median_face_boxFalse/saved_test_outputs/UBFC_UBFC_UBFC_physnet_stan_outputs.pickle
